# %%
# https://www.perplexity.ai/search/dbe2dcd6-bbdf-488c-9e30-da78af563e02

# %%
from matplotlib.font_manager import fontManager
import matplotlib as mpl

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font',family='ChineseFont')

# %%
import matplotlib.pyplot as plt

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}

subjects = list(student1.keys()) # Get the subjects from student1
# subjects = list(student1.keys()) + list(student2.keys())  # Combine subjects from both students
student1_value = list(student1.values())
student2_value = list(student2.values())

figure = plt.figure(figsize=(8, 5),dpi=150,facecolor='#eeeeee') # Create a figure with specified size and DPI;背景顏色16進制6個數字
axes = figure.add_subplot(1,1,1)
plt.show()

# %%
import matplotlib.pyplot as plt

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}

subjects = list(student1.keys())
student1_value = list(student1.values())
student2_value = list(student2.values())

figure = plt.figure(figsize=(8, 5),dpi=150,facecolor='#eeeeee')
axes = figure.add_subplot(1,1,1)
axes.plot(subjects,student1_value,marker='o',label="徐xx")
axes.plot(subjects,student2_value,marker='o',linestyle='-.',label="張xx")
axes.set_title("張xx vs 徐xx")
axes.set_xlabel("科目")
axes.set_ylabel("分數")
axes.legend() # Add a legend to differentiate between the two students
axes.grid(axis='y',color='blue',alpha=0.1,linestyle=':') # Add grid lines for better readability 
# alpha: 透明度, 0.0 (完全透明) 到 1.0 (完全不透明)
# linestyle: 線條樣式, 'solid' (實線), 'dashed' (虛線), 'dashdot' (點劃線), 'dotted' (點線)

plt.show()

# %%
import matplotlib.pyplot as plt

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}

subjects = list(student1.keys())
student1_value = list(student1.values())
student2_value = list(student2.values())

figure = plt.figure(figsize=(8, 5),dpi=150,facecolor='#eeeeee')
axes = figure.add_subplot(1,1,1)
axes.plot(subjects,student1_value,marker='o',label="徐xx")
axes.plot(subjects,student2_value,marker='o',linestyle='-.',label="張xx")
axes.set_title("張xx vs 徐xx")
axes.set_xlabel("科目")
axes.set_ylabel("分數")
axes.legend()
xlocations = axes.get_xticks() # Get the x-axis locations for the subjects
# xlocations will be used to place annotations above the points
for index in range(len(xlocations)): # Iterate through each subject
    # print("index:",index)
    x = xlocations[index]
    student1_y = student1_value[index]
    student2_y = student2_value[index]
    # print("x座標:",x)
    # print("s1_y_座標:",student1_y)
    # print("s2_y_座標:",student2_y)
    # print("==================")
    axes.annotate(str(student1_y),(x-0.05,student1_y+1))# 在每個點上方標註學生1的分數, x-0.05是為了讓標註不會與點重疊, y+1是為了讓標註在點的上方
    axes.annotate(str(student2_y),(x-0.05,student2_y+1))# 在每個點上方標註學生2的分數
axes.grid(axis='y',color='blue',alpha=0.1,linestyle=':')
plt.show()

# %%
import matplotlib.pyplot as plt

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}

subjects = list(student1.keys())
student1_value = list(student1.values())
student2_value = list(student2.values())

figure = plt.figure(figsize=(8, 5),dpi=150,facecolor='#eeeeee')
axes = figure.add_subplot(1,1,1)
axes.plot(subjects,student1_value,marker='o',label="徐xx")
axes.plot(subjects,student2_value,marker='o',linestyle='-.',label="張xx")
axes.set_title("張xx vs 徐xx")
axes.set_xlabel("科目")
axes.set_ylabel("分數")
axes.legend()
xlocations = axes.get_xticks()
for index in range(len(xlocations)):
    x = xlocations[index]
    student1_y = student1_value[index]
    student2_y = student2_value[index]
    # print("x座標:",x)
    # print("s1_y_座標:",student1_y)
    # print("s2_y_座標:",student2_y)
    # print("==================")
    axes.annotate(str(student1_y),(x-0.05,student1_y+1))
    axes.annotate(str(student2_y),(x-0.05,student2_y+1))
    axes.set_xlim(-0.5,4.5) # Set x-axis limits to ensure all subjects are visible
    axes.set_ylim(60,105) # Set y-axis limits to ensure all scores are visible
axes.grid(axis='y',color='blue',alpha=0.1,linestyle=':')
plt.show()

# %%
from matplotlib.font_manager import fontManager
import matplotlib as mpl

fontManager.addfont("ChineseFont.ttf")
mpl.rc('font',family='ChineseFont')
import matplotlib.pyplot as plt

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}

subjects = list(student1.keys())
student1_value = list(student1.values())
student2_value = list(student2.values())

figure = plt.figure(figsize=(8, 5),dpi=150,facecolor='#eeeeee')
axes = figure.add_subplot(1,1,1)
axes.plot(subjects,student1_value,marker='o',label="徐xx")
axes.plot(subjects,student2_value,marker='o',linestyle='-.',label="張xx")
axes.set_title("張xx vs 徐xx")
axes.set_xlabel("科目")
axes.set_ylabel("分數")
axes.legend()
xlocations = axes.get_xticks()
for index in range(len(xlocations)):
    x = xlocations[index]
    student1_y = student1_value[index]
    student2_y = student2_value[index]
    # print("x座標:",x)
    # print("s1_y_座標:",student1_y)
    # print("s2_y_座標:",student2_y)
    # print("==================")
    axes.annotate(str(student1_y),(x-0.05,student1_y+1))
    if student2_y == 98:
        axes.annotate(str(student2_y),(x,student2_y),xytext=(x, student2_y+5), arrowprops=dict(facecolor='black', shrink=0.05))
    else:
        axes.annotate(str(student2_y),(x-0.05,student2_y+1))
    axes.set_xlim(-0.5,4.5)
    axes.set_ylim(60,105)
axes.grid(axis='y',color='blue',alpha=0.1,linestyle=':')
plt.show()

# %%
import matplotlib.pyplot as plt

student1 = {'國文':78, '英文':80, '數學':92, '歷史':75, '探索':85}
student2 = {'國文':90, '英文':75, '數學':98, '歷史':65, '探索':75}

subjects = list(student1.keys())
student1_value = list(student1.values())
student2_value = list(student2.values())

figure = plt.figure(figsize=(8, 5),dpi=150,facecolor='#eeeeee')
axes = figure.add_subplot(1,1,1)
axes.plot(subjects,student1_value,marker='o',label="徐xx")
axes.plot(subjects,student2_value,marker='o',linestyle='-.',label="張xx")
axes.set_title("張xx vs 徐xx")
axes.set_xlabel("科目")
axes.set_ylabel("分數")
axes.legend()
xlocations = axes.get_xticks()
for index in range(len(xlocations)):
    x = xlocations[index]
    student1_y = student1_value[index]
    student2_y = student2_value[index]
    # print("x座標:",x)
    # print("s1_y_座標:",student1_y)
    # print("s2_y_座標:",student2_y)
    # print("==================")
    axes.annotate(str(student1_y),(x-0.05,student1_y+1))
    if student2_y == 98:
        axes.annotate(str(student2_y),(x,student2_y),xytext=(x, student2_y+5), arrowprops=dict(facecolor='red', shrink=0.05))
    else:
        axes.annotate(str(student2_y),(x-0.05,student2_y+1))
    axes.set_xlim(-0.5,4.5)
    axes.set_ylim(60,105)
axes.grid(axis='y',color='blue',alpha=0.1,linestyle=':')
plt.show()
