# %% [markdown]
# https://www.perplexity.ai/search/8906abee-eea5-4924-8e07-f2f2029af740

# %%
import numpy as np
import pandas as pd
#建立50位學生5個分數,每個分數的值是50~100之間的隨機整數
scores = np.random.randint(50,101,size=(50, 5))
score_pd = pd.DataFrame(scores,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index=[f'學生{index}' for index in range(1,51)])
type(score_pd.index)
score_pd.columns.name = '科目'
score_pd.index.name = '學號'
score_pd
#將分數轉換為百分制
score_pd = score_pd / 100

# %%
import numpy as np
import pandas as pd
#建立50位學生5個分數,每個分數的值是50~100之間的隨機整數
scores = np.random.randint(50,101,size=(50, 5))
score_pd = pd.DataFrame(scores,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index=[f'學生{index}' for index in range(1,51)])
type(score_pd.index)
score_pd.columns.name = '科目' #設定columns的名稱
score_pd.index.name = '學號' #設定index的名稱
sum_series = np.sum(score_pd, axis=1)
mean_series = score_pd.mean(axis=1)
score_pd['總分'] = sum_series #將總分加入到DataFrame中
score_pd['平均'] = mean_series #將平均加入到DataFrame中

# %%
score_pd.sort_values(by='總分', ascending=False)
# Out:
# 科目     國文   英文   數學   地理   歷史   總分    平均
# 學號
# 學生42   84  100   97   93   91  465  93.0
# 學生49  100   96   83  100   63  442  88.4
# 學生37   67   87   95   95   96  440  88.0
# 學生1    69  100  100  100   65  434  86.8
# 學生18   84   69   97   96   83  429  85.8
# 學生31   93   77   69   94   87  420  84.0
# 學生29   94   94   50   92   90  420  84.0
# 學生47   94   85   91   78   66  414  82.8
# 學生17   86   62   78   85   98  409  81.8
# 學生39   97   78   81   69   82  407  81.4
# 學生23   98   85   58   68   92  401  80.2
# 學生35   86   65   89   78   82  400  80.0
# 學生41   72   92   95   61   79  399  79.8
# 學生3    98   80   76   69   75  398  79.6
# 學生12   62   87  100   91   57  397  79.4
# 學生33   86   70   93   77   70  396  79.2
# 學生19   54   56   99   93   94  396  79.2
# 學生7    70   93   90   62   77  392  78.4
# 學生2    90   75   59   97   71  392  78.4
# 學生6    81   74   62   91   83  391  78.2
# 學生8    94   51   81   88   77  391  78.2
# 學生24   93   94   83   61   57  388  77.6
# 學生38   78   56   89   63  100  386  77.2
# 學生10   95   99   54   54   83  385  77.0
# 學生25   63   74   72   97   79  385  77.0
# 學生16   72   79   65   70   98  384  76.8
# 學生34   92   92   73   70   55  382  76.4
# 學生36   84   96   86   64   50  380  76.0
# 學生11   83   83   63   91   55  375  75.0
# 學生44   50   73   94   61   87  365  73.0
# 學生28   93   77   54   68   67  359  71.8
# 學生22   56   65   89   74   75  359  71.8
# 學生45   57   96   76   73   56  358  71.6
# 學生46   84   79   51   84   59  357  71.4
# 學生4    71   73   59   92   62  357  71.4
# 學生27   91   69   78   50   69  357  71.4
# 學生50   53   75   70   73   84  355  71.0
# 學生30   73   58   58   97   69  355  71.0
# 學生40   70   86   83   52   62  353  70.6
# 學生43   98   53   68   65   68  352  70.4
# 學生14   71   69   79   61   67  347  69.4
# 學生21   57   53   70   94   68  342  68.4
# 學生32   88   73   68   59   50  338  67.6
# 學生26   82   71   64   60   61  338  67.6
# 學生48   52   92   82   55   51  332  66.4
# 學生20   59   85   82   51   52  329  65.8
# 學生13   52  100   54   61   59  326  65.2
# 學生15   56   74   68   62   64  324  64.8
# 學生9    79   52   76   50   63  320  64.0
# 學生5    57   77   56   50   74  314  62.8

# %%
score_pd.sort_values(by='總分', ascending=True)
# Out:
# 科目     國文   英文   數學   地理   歷史   總分    平均
# 學號
# 學生5    57   77   56   50   74  314  62.8
# 學生9    79   52   76   50   63  320  64.0
# 學生15   56   74   68   62   64  324  64.8
# 學生13   52  100   54   61   59  326  65.2
# 學生20   59   85   82   51   52  329  65.8
# 學生48   52   92   82   55   51  332  66.4
# 學生32   88   73   68   59   50  338  67.6
# 學生26   82   71   64   60   61  338  67.6
# 學生21   57   53   70   94   68  342  68.4
# 學生14   71   69   79   61   67  347  69.4
# 學生43   98   53   68   65   68  352  70.4
# 學生40   70   86   83   52   62  353  70.6
# 學生50   53   75   70   73   84  355  71.0
# 學生30   73   58   58   97   69  355  71.0
# 學生27   91   69   78   50   69  357  71.4
# 學生4    71   73   59   92   62  357  71.4
# 學生46   84   79   51   84   59  357  71.4
# 學生45   57   96   76   73   56  358  71.6
# 學生28   93   77   54   68   67  359  71.8
# 學生22   56   65   89   74   75  359  71.8
# 學生44   50   73   94   61   87  365  73.0
# 學生11   83   83   63   91   55  375  75.0
# 學生36   84   96   86   64   50  380  76.0
# 學生34   92   92   73   70   55  382  76.4
# 學生16   72   79   65   70   98  384  76.8
# 學生25   63   74   72   97   79  385  77.0
# 學生10   95   99   54   54   83  385  77.0
# 學生38   78   56   89   63  100  386  77.2
# 學生24   93   94   83   61   57  388  77.6
# 學生6    81   74   62   91   83  391  78.2
# 學生8    94   51   81   88   77  391  78.2
# 學生2    90   75   59   97   71  392  78.4
# 學生7    70   93   90   62   77  392  78.4
# 學生19   54   56   99   93   94  396  79.2
# 學生33   86   70   93   77   70  396  79.2
# 學生12   62   87  100   91   57  397  79.4
# 學生3    98   80   76   69   75  398  79.6
# 學生41   72   92   95   61   79  399  79.8
# 學生35   86   65   89   78   82  400  80.0
# 學生23   98   85   58   68   92  401  80.2
# 學生39   97   78   81   69   82  407  81.4
# 學生17   86   62   78   85   98  409  81.8
# 學生47   94   85   91   78   66  414  82.8
# 學生31   93   77   69   94   87  420  84.0
# 學生29   94   94   50   92   90  420  84.0
# 學生18   84   69   97   96   83  429  85.8
# 學生1    69  100  100  100   65  434  86.8
# 學生37   67   87   95   95   96  440  88.0
# 學生49  100   96   83  100   63  442  88.4
# 學生42   84  100   97   93   91  465  93.0

# %%
sorted_pd = score_pd.sort_values(by='總分',ascending=False)
rand_series = sorted_pd['總分'].rank(ascending=False,method='min')
sorted_pd['名次'] = rand_series

sorted_pd
# Out:
# 科目     國文   英文   數學   地理   歷史   總分    平均    名次
# 學號
# 學生42   84  100   97   93   91  465  93.0   1.0
# 學生49  100   96   83  100   63  442  88.4   2.0
# 學生37   67   87   95   95   96  440  88.0   3.0
# 學生1    69  100  100  100   65  434  86.8   4.0
# 學生18   84   69   97   96   83  429  85.8   5.0
# 學生31   93   77   69   94   87  420  84.0   6.0
# 學生29   94   94   50   92   90  420  84.0   6.0
# 學生47   94   85   91   78   66  414  82.8   8.0
# 學生17   86   62   78   85   98  409  81.8   9.0
# 學生39   97   78   81   69   82  407  81.4  10.0
# 學生23   98   85   58   68   92  401  80.2  11.0
# 學生35   86   65   89   78   82  400  80.0  12.0
# 學生41   72   92   95   61   79  399  79.8  13.0
# 學生3    98   80   76   69   75  398  79.6  14.0
# 學生12   62   87  100   91   57  397  79.4  15.0
# 學生33   86   70   93   77   70  396  79.2  16.0
# 學生19   54   56   99   93   94  396  79.2  16.0
# 學生7    70   93   90   62   77  392  78.4  18.0
# 學生2    90   75   59   97   71  392  78.4  18.0
# 學生6    81   74   62   91   83  391  78.2  20.0
# 學生8    94   51   81   88   77  391  78.2  20.0
# 學生24   93   94   83   61   57  388  77.6  22.0
# 學生38   78   56   89   63  100  386  77.2  23.0
# 學生10   95   99   54   54   83  385  77.0  24.0
# 學生25   63   74   72   97   79  385  77.0  24.0
# 學生16   72   79   65   70   98  384  76.8  26.0
# 學生34   92   92   73   70   55  382  76.4  27.0
# 學生36   84   96   86   64   50  380  76.0  28.0
# 學生11   83   83   63   91   55  375  75.0  29.0
# 學生44   50   73   94   61   87  365  73.0  30.0
# 學生28   93   77   54   68   67  359  71.8  31.0
# 學生22   56   65   89   74   75  359  71.8  31.0
# 學生45   57   96   76   73   56  358  71.6  33.0
# 學生46   84   79   51   84   59  357  71.4  34.0
# 學生4    71   73   59   92   62  357  71.4  34.0
# 學生27   91   69   78   50   69  357  71.4  34.0
# 學生50   53   75   70   73   84  355  71.0  37.0
# 學生30   73   58   58   97   69  355  71.0  37.0
# 學生40   70   86   83   52   62  353  70.6  39.0
# 學生43   98   53   68   65   68  352  70.4  40.0
# 學生14   71   69   79   61   67  347  69.4  41.0
# 學生21   57   53   70   94   68  342  68.4  42.0
# 學生32   88   73   68   59   50  338  67.6  43.0
# 學生26   82   71   64   60   61  338  67.6  43.0
# 學生48   52   92   82   55   51  332  66.4  45.0
# 學生20   59   85   82   51   52  329  65.8  46.0
# 學生13   52  100   54   61   59  326  65.2  47.0
# 學生15   56   74   68   62   64  324  64.8  48.0
# 學生9    79   52   76   50   63  320  64.0  49.0
# 學生5    57   77   56   50   74  314  62.8  50.0
