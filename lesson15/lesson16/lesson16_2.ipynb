# %%
import numpy as np
import pandas as pd
#建立50位學生5個分數,每個分數的值是50~100之間的隨機整數
scores = np.random.randint(50,101,size=(50, 5))
score_pd = pd.DataFrame(scores,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index=[f'學生{index}' for index in range(1,51)])
type(score_pd.index)
score_pd.columns.name = '科目'
score_pd.index.name = '學號'
score_pd
# sum_series = np.sum(score_pd, axis=1)
# mean_series = score_pd.mean(axis=1)
# Out:
# 科目     國文  英文   數學  地理   歷史
# 學號
# 學生1    57  79   65  77   91
# 學生2    97  92   71  87   74
# 學生3    89  69   67  80   55
# 學生4    56  83   59  76   92
# 學生5    79  89   74  55   62
# 學生6    60  91   78  99   84
# 學生7    87  98   96  96   85
# 學生8    74  77   93  89   96
# 學生9    64  60   69  95   55
# 學生10   51  78   68  90   69
# 學生11   73  57   75  87   94
# 學生12   52  89   72  52   88
# 學生13   51  89   87  52   91
# 學生14   78  74   88  64   60
# 學生15   73  86   88  82   83
# 學生16   74  60   61  83   93
# 學生17   77  91   84  76   57
# 學生18   69  80   68  89   67
# 學生19   54  83   94  91   79
# 學生20  100  68  100  95   52
# 學生21   59  65   60  54   55
# 學生22   51  81   51  82   90
# 學生23   86  96   80  65   95
# 學生24   90  99   81  98   67
# 學生25   51  90   80  84   56
# 學生26   95  59   57  52   66
# 學生27   86  82   93  62   89
# 學生28   96  70   97  78   82
# 學生29   86  70   91  62  100
# 學生30   96  58   67  76   99
# 學生31   73  57   72  78   58
# 學生32   51  70   84  80  100
# 學生33   50  91   51  63   91
# 學生34   83  82   95  60   50
# 學生35   68  99   70  91   59
# 學生36   50  54   75  84   59
# 學生37   76  93   59  85   64
# 學生38   56  78   77  60  100
# 學生39   75  54   69  72   54
# 學生40   58  72   75  82   54
# 學生41   95  98  100  70   82
# 學生42   88  85  100  63   68
# 學生43   91  85   51  83   69
# 學生44   82  82   79  87   96
# 學生45   89  67   70  65   85
# 學生46   76  89   98  59   62
# 學生47   89  91   99  69   57
# 學生48   80  52   69  54   61
# 學生49   73  90   57  75   56
# 學生50   77  99   98  51   55

# %%
import numpy as np
import pandas as pd
#建立50位學生5個分數,每個分數的值是50~100之間的隨機整數
scores = np.random.randint(50,101,size=(50, 5))
score_pd = pd.DataFrame(scores,
             columns=['國文', '英文', '數學', '地理', '歷史'],
             index=[f'學生{index}' for index in range(1,51)])
type(score_pd.index)
score_pd.columns.name = '科目'
score_pd.index.name = '學號'
sum_series = np.sum(score_pd, axis=1)
mean_series = score_pd.mean(axis=1)
score_pd['總分'] = sum_series
score_pd['平均'] = mean_series

# %%
score_pd
# Out:
# 科目     國文   英文   數學  地理   歷史   總分    平均
# 學號
# 學生1    94   61   78  74   94  401  80.2
# 學生2    82   70   94  57   86  389  77.8
# 學生3    84   98   77  88   66  413  82.6
# 學生4    89   90   84  77   74  414  82.8
# 學生5    52   92   92  62   96  394  78.8
# 學生6    99   76   67  78   78  398  79.6
# 學生7    75   84   91  56   62  368  73.6
# 學生8    78   84   73  89   69  393  78.6
# 學生9    93   80   86  72   96  427  85.4
# 學生10   57   99   97  55   85  393  78.6
# 學生11   92   92   77  65   58  384  76.8
# 學生12   70   84   59  52   83  348  69.6
# 學生13   67   77   89  66   71  370  74.0
# 學生14   80   90   75  95   52  392  78.4
# 學生15   62   70   96  70   79  377  75.4
# 學生16   83   78   50  62   51  324  64.8
# 學生17   95   61   79  73   58  366  73.2
# 學生18   76   89   80  63   91  399  79.8
# 學生19   78   78   76  55   53  340  68.0
# 學生20   77   60   86  55   93  371  74.2
# 學生21   95   61  100  76   93  425  85.0
# 學生22   60   73   84  89   79  385  77.0
# 學生23   55   94   70  63   83  365  73.0
# 學生24   98   52   72  58   51  331  66.2
# 學生25  100   62   67  73   58  360  72.0
# 學生26   64   63   96  60   62  345  69.0
# 學生27   64   93   51  91   57  356  71.2
# 學生28   94   95   82  52   67  390  78.0
# 學生29   92   72   64  52   68  348  69.6
# 學生30   53   61   93  90   80  377  75.4
# 學生31   66   92   88  52   53  351  70.2
# 學生32   90   52   82  61   52  337  67.4
# 學生33   85   88   61  79   89  402  80.4
# 學生34   89   95   93  79   61  417  83.4
# 學生35   61   59   50  77   57  304  60.8
# 學生36   81   89   77  85   55  387  77.4
# 學生37   72   91   96  97   96  452  90.4
# 學生38   96   80   91  87   80  434  86.8
# 學生39   54   78   94  96  100  422  84.4
# 學生40   64   79   85  75   83  386  77.2
# 學生41   57   60   73  63   64  317  63.4
# 學生42   84   64   80  76   66  370  74.0
# 學生43   77   95   97  73   96  438  87.6
# 學生44   64   73   62  80   77  356  71.2
# 學生45   64   50   99  59   95  367  73.4
# 學生46   95  100   88  72   79  434  86.8
# 學生47   55  100   50  63   57  325  65.0
# 學生48   82   56   51  89   77  355  71.0
# 學生49   70   89   81  57   64  361  72.2
# 學生50   53   74   50  59   86  322  64.4
